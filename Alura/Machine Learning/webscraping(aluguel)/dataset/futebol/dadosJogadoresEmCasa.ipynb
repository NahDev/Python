# %%
import pandas as pd

# %%
df1 = pd.read_excel('geralforacasa/Geral/defensivoJogadoresBrasileirãoGeral.ods', index_col='Jogador')
df2 = pd.read_excel('geralforacasa/Geral/ofensivoJogadoresBrasileirãoGeral.ods', index_col='Jogador')
df3 = pd.read_excel('geralforacasa/Geral/passesJogadoresBrasileirãoGeral.ods', index_col='Jogador')
# df4 = pd.read_excel('geralforacasa/Fora/resumoJogadoresBrasileirãoFora.ods', index_col='Jogador')

# %%
df1.shape

concateado = pd.concat([df1,df2,df3], axis=1)

# %%
concateado.to_csv('Estatistica em geral.csv',sep=',')

# %%
# Out:
#                                                                                          Player  \
# Jogador
# Gustavo ScarpaPalmeiras, 28, D(L),M(CLR)              1Gustavo ScarpaPalmeiras, 28, D(L),M(CLR)
# Giorgian de ArrascaetaFlamengo, 28, AM(CLR),FW  2Giorgian de ArrascaetaFlamengo, 28, AM(CLR),FW
# Marcos RochaPalmeiras, 33, D(R),M(R)                      3Marcos RochaPalmeiras, 33, D(R),M(R)
# DiegoGoias, 26, D(R),M(R)                                            4DiegoGoias, 26, D(R),M(R)
# Igor PaixãoCoritiba, 22, AM(L)                                  5Igor PaixãoCoritiba, 22, AM(L)
# ...                                                                                         ...
# Silvio RomeroFortaleza, 34, AM(R),FW                    356Silvio RomeroFortaleza, 34, AM(R),FW
# RégisCoritiba, 29, AM(C)                                            357RégisCoritiba, 29, AM(C)
# Eric RamiresRed Bull Bragantino, 22, M(CR)        358Eric RamiresRed Bull Bragantino, 22, M(CR)
# ...
